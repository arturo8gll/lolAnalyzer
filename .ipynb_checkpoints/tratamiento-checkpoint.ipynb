# %%
import pygal
import numpy as np
import pandas as pd
from scipy.stats import ks_2samp
from scipy.stats import chisquare

# %matplotlib inline

# %%
def test_ks_2samp(df1,df2):
    table = pd.DataFrame()
    pvalue = []
    si = []
    variables=separateVarCD(df1)
    for i in variables[0]:
        pvalue.append(ks_2samp(df1[i],df2[i])[1])
        si.append('false' if ks_2samp(df1[i],df2[i])[1]<.05 else'true')
    table['variable'] = variables[0]
    table['p_value']=pvalue
    table['son iguales']=si
    return table

# %%
def separateVarCD(df):
    """
    Esta funcion separa las variables continuas y discretas.
    
    si la variable es de tipo 'float64' o 'int64' se clasifica como continua
    si la variable es de otro tipo se clasifica como discreta
    """
    ls_cont = []
    ls_disc = []
    for i in range(0,len(df.columns)):
        if train.dtypes[i] == 'int64' or train.dtypes[i] == 'float64':
            ls_cont.append(df.columns[i])
        else:
            ls_disc.append(df.columns[i])
    return ls_cont,ls_disc

# %%
train = pd.read_csv('./csv/train.csv')
test = pd.read_csv('./csv/test.csv')

train["gameId"] = train["gameId"].astype(str)
train["platformId"] = train["platformId"].astype(str)
train["gameDuration"] = train["gameDuration"].astype(str)
train["gameCreation"] = train["gameCreation"].astype(str)
train["queueId"] = train["queueId"].astype(str)
train["mapId"] = train["mapId"].astype(str)
train["seasonId"] = train["seasonId"].astype(str)
train["teamId"] = train["teamId"].astype(str)
train["participantId"] = train["participantId"].astype(str)
train["championId"] = train["championId"].astype(str)


test["gameId"] = test["gameId"].astype(str)
test["platformId"] = test["platformId"].astype(str)
test["gameDuration"] = test["gameDuration"].astype(str)
test["gameCreation"] = test["gameCreation"].astype(str)
test["queueId"] = test["queueId"].astype(str)
test["mapId"] = test["mapId"].astype(str)
test["seasonId"] = test["seasonId"].astype(str)
test["teamId"] = test["teamId"].astype(str)
test["participantId"] = test["participantId"].astype(str)
test["championId"] = test["championId"].astype(str)

# %%
train.head()
# Out:
#    Unnamed: 0     gameId platformId   gameCreation gameDuration queueId mapId  \
# 0          46  626336825        LA1  1541396421086         2262     420    11
# 1          88  517793295        LA1  1516570412563         1222     420    11
# 2          62  614019404        LA1  1538692284892          197     420    11
# 3          98  478344211        LA1  1507658443871         1370     420    11
# 4          43  636354217        LA1  1543650236174         2171     420    11
#
#   seasonId    gameVersion gameMode  ... damageTakenDiffPerMinDeltas_20-30  \
# 0       11  8.21.251.4430  CLASSIC  ...                              64.0
# 1       11   8.1.214.5847  CLASSIC  ...                               NaN
# 2       11  8.19.246.5109  CLASSIC  ...                               NaN
# 3        9  7.19.203.1070  CLASSIC  ...                               NaN
# 4       12   8.23.254.717  CLASSIC  ...                             239.2
#
#      lane       role  creepsPerMinDeltas_30-end  xpPerMinDeltas_30-end  \
# 0  BOTTOM  DUO_CARRY                        5.2                  359.0
# 1  JUNGLE       NONE                        NaN                    NaN
# 2    NONE        DUO                        NaN                    NaN
# 3  JUNGLE       NONE                        NaN                    NaN
# 4     TOP       SOLO                        2.0                  385.2
#
#    goldPerMinDeltas_30-end  damageTakenPerMinDeltas_30-end  \
# 0                    477.2                          1136.6
# 1                      NaN                             NaN
# 2                      NaN                             NaN
# 3                      NaN                             NaN
# 4                    309.2                          1897.0
#
#    csDiffPerMinDeltas_30-end  xpDiffPerMinDeltas_30-end  \
# 0                       -2.3                     -108.7
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                       -4.2                     -372.0
#
#    damageTakenDiffPerMinDeltas_30-end
# 0                               -16.1
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                              1280.4
#
# [5 rows x 162 columns]

# %%
test.head()
# Out:
#    Unnamed: 0     gameId platformId   gameCreation gameDuration queueId mapId  \
# 0          80  519536557        LA1  1516954735260         1214     420    11
# 1           9  657382202        LA1  1548535621078         1616     420    11
# 2          25  651782540        LA1  1547184206622         1587     420    11
# 3          87  517779980        LA1  1516573437676         1801     420    11
# 4          79  593728924        LA1  1534034075567          199     420    11
#
#   seasonId    gameVersion gameMode  ... damageTakenDiffPerMinDeltas_20-30  \
# 0       11    8.2.215.824  CLASSIC  ...                               NaN
# 1       13   9.2.261.2172  CLASSIC  ...                               NaN
# 2       12   9.1.257.7563  CLASSIC  ...                               NaN
# 3       11   8.1.214.5847  CLASSIC  ...                             643.1
# 4       11  8.15.239.9021  CLASSIC  ...                               NaN
#
#      lane  role  creepsPerMinDeltas_30-end  xpPerMinDeltas_30-end  \
# 0  JUNGLE  NONE                        NaN                    NaN
# 1     TOP  SOLO                        NaN                    NaN
# 2     TOP  SOLO                        NaN                    NaN
# 3  JUNGLE  NONE                        NaN                    NaN
# 4    NONE   DUO                        NaN                    NaN
#
#    goldPerMinDeltas_30-end  damageTakenPerMinDeltas_30-end  \
# 0                      NaN                             NaN
# 1                      NaN                             NaN
# 2                      NaN                             NaN
# 3                      NaN                             NaN
# 4                      NaN                             NaN
#
#    csDiffPerMinDeltas_30-end  xpDiffPerMinDeltas_30-end  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
#
#    damageTakenDiffPerMinDeltas_30-end
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
# [5 rows x 162 columns]

# %%
ls_cont,ls_disc = separateVarCD(train)

# %%
test_ks_2samp(train,test)
# Out:
#                                variable   p_value son iguales
# 0                            Unnamed: 0  0.715005        true
# 1                            towerKills  0.392315        true
# 2                        inhibitorKills  1.000000        true
# 3                            baronKills  1.000000        true
# 4                           dragonKills  0.909511        true
# 5                          vilemawKills  1.000000        true
# 6                       riftHeraldKills  0.987363        true
# 7                  dominionVictoryScore  1.000000        true
# 8                              spell1Id  1.000000        true
# 9                              spell2Id  0.999995        true
# 10                                item0  0.362018        true
# 11                                item1  0.951503        true
# 12                                item2  0.256491        true
# 13                                item3  0.966953        true
# 14                                item4  0.564174        true
# 15                                item5  0.821938        true
# 16                                item6  1.000000        true
# 17                                kills  0.143346        true
# 18                               deaths  0.932335        true
# 19                              assists  0.951503        true
# 20                  largestKillingSpree  0.601555        true
# 21                     largestMultiKill  0.751982        true
# 22                        killingSprees  0.987363        true
# 23               longestTimeSpentLiving  0.424110        true
# 24                          doubleKills  0.821938        true
# 25                          tripleKills  1.000000        true
# 26                          quadraKills  1.000000        true
# 27                           pentaKills  1.000000        true
# 28                          unrealKills  1.000000        true
# 29                     totalDamageDealt  0.932335        true
# ..                                  ...       ...         ...
# 103                           statPerk1  1.000000        true
# 104                           statPerk2  0.951503        true
# 105            creepsPerMinDeltas_10-20  0.987363        true
# 106             creepsPerMinDeltas_0-10  0.821938        true
# 107            creepsPerMinDeltas_20-30  0.564174        true
# 108                xpPerMinDeltas_10-20  0.932335        true
# 109                 xpPerMinDeltas_0-10  0.787791        true
# 110                xpPerMinDeltas_20-30  0.306099        true
# 111              goldPerMinDeltas_10-20  0.677330        true
# 112               goldPerMinDeltas_0-10  0.601555        true
# 113              goldPerMinDeltas_20-30  0.491846        true
# 114            csDiffPerMinDeltas_10-20  0.035859       false
# 115             csDiffPerMinDeltas_0-10  0.564174        true
# 116            csDiffPerMinDeltas_20-30  0.951503        true
# 117            xpDiffPerMinDeltas_10-20  0.175491        true
# 118             xpDiffPerMinDeltas_0-10  0.639385        true
# 119            xpDiffPerMinDeltas_20-30  0.909511        true
# 120       damageTakenPerMinDeltas_10-20  0.853921        true
# 121        damageTakenPerMinDeltas_0-10  0.987363        true
# 122       damageTakenPerMinDeltas_20-30  0.564174        true
# 123   damageTakenDiffPerMinDeltas_10-20  0.978804        true
# 124    damageTakenDiffPerMinDeltas_0-10  0.751982        true
# 125   damageTakenDiffPerMinDeltas_20-30  0.932335        true
# 126           creepsPerMinDeltas_30-end  0.787791        true
# 127               xpPerMinDeltas_30-end  0.999852        true
# 128             goldPerMinDeltas_30-end  0.987363        true
# 129      damageTakenPerMinDeltas_30-end  1.000000        true
# 130           csDiffPerMinDeltas_30-end  0.987363        true
# 131           xpDiffPerMinDeltas_30-end  1.000000        true
# 132  damageTakenDiffPerMinDeltas_30-end  1.000000        true
#
# [133 rows x 3 columns]

# %%
def test_chisquare(df1,df2):
    table = pd.DataFrame()
    pvalue = []
    si = []
    variables=separateVarCD(df1)
    for i in variables[1]:
        pvalue.append(chisquare(df1[i].value_counts().sort_index(),df2[i].value_counts().sort_index())[1])
        si.append('true' if chisquare(df1[i].value_counts().sort_index(),df2[i].value_counts().sort_index())[1] <.05 else'false')
    table['variable'] = variables[0]
    table['p_value']=pvalue
    table['son iguales']=si
    return table
# Out:
#   File "<ipython-input-16-0664bfe021df>", line 7
#     pvalue.append(chisquare(df1[i].value_counts().sort_index(),df2[i].value_counts().sort_index())[1)
#                                                                                                     ^
# SyntaxError: invalid syntax

# %%
test_chisquare(train,test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-dfe8e8ce869a> in <module>
# ----> 1 test_chisquare(train,test)
#
# <ipython-input-14-0ca84645fefe> in test_chisquare(df1, df2)
#       6     for i in variables[1]:
#       7         pvalue.append(ks_2samp(df1[i],df2[i])[1])
# ----> 8         si.append('true' if chisquare(df1[i].value_counts().sort_index(),df2[i].value_counts().sort_index())[1] <.05 else'false')
#       9     table['variable'] = variables[0]
#      10     table['p_value']=pvalue
#
# ~/virtualenv/unam/lib/python3.7/site-packages/scipy/stats/stats.py in chisquare(f_obs, f_exp, ddof, axis)
#    4785     """
#    4786     return power_divergence(f_obs, f_exp=f_exp, ddof=ddof, axis=axis,
# -> 4787                             lambda_="pearson")
#    4788
#    4789
#
# ~/virtualenv/unam/lib/python3.7/site-packages/scipy/stats/stats.py in power_divergence(f_obs, f_exp, ddof, axis, lambda_)
#    4651     if lambda_ == 1:
#    4652         # Pearson's chi-squared statistic
# -> 4653         terms = (f_obs - f_exp)**2 / f_exp
#    4654     elif lambda_ == 0:
#    4655         # Log-likelihood ratio (i.e. G-test)
#
# ValueError: operands could not be broadcast together with shapes (70,) (30,)
